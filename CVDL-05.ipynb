# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve2d

# %%
np.random.seed(1)

# %%
image = np.random.rand(32, 32)
plt.imshow(image, cmap='viridis')
plt.title("Original Image")
plt.axis('off')
plt.show()

# %%
kernel = np.array([[1, 0, -1],
[1, 0, -1],
[1, 0, -1]])

# %%
convolved = convolve2d(image, kernel, mode='same') # 'same' keeps the output size the same
plt.imshow(convolved, cmap='viridis') # Change colormap to 'viridis'
plt.title("After Convolution")
plt.axis('off')
plt.show()

# %%
relu_output = np.maximum(0, convolved)
plt.imshow(relu_output, cmap='viridis')
plt.title("After ReLU Activation")
plt.axis('off')
plt.show()

# %%
def max_pooling(image, pool_size=2, stride=2):
    output_shape = (
        (image.shape[0] - pool_size) // stride + 1,
        (image.shape[1] - pool_size) // stride + 1
    )

    pooled = np.zeros(output_shape)
    for i in range(0, image.shape[0] - pool_size + 1, stride):
        for j in range(0, image.shape[1] - pool_size + 1, stride):
            pooled[i // stride, j // stride] = np.max(image[i:i + pool_size, j:j + pool_size])
    return pooled

# %%
pooled_output = max_pooling(relu_output)
plt.imshow(pooled_output, cmap='viridis')
plt.title("After Max Pooling")
plt.axis('off')
plt.show()
